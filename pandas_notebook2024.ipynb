# %% [markdown]
# pandas is a python module that makes data science easy and effective
#
# process of cleaning messy data is called data munging or data wrangling

# %% [markdown]
# df - it is the main object in pandas ,it is used to represent tabular data such as rows and columns like excel

# %% [markdown]
# # pandas 1)  topics
#
# ## 1)creating data frame
# ## 2)dealing with rows and columns
# ## 3)min ,max ,std,describe
# ## 4)conditional selection
# ## 5)set_index

# %%
import pandas as pd


df = pd.read_csv("C:\\Users\\Acer\\Downloads\\car-sales-extended-missing-data.csv")
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
# instead of this we can create a data frame and it is also we can import 

name = {
    "name": ["junais"],
    "age": [23],
    "gender": ["male"]   #if we create normal data frame the value of dict should be iterable , use a list then only it will work
}

df1 = pd.DataFrame(name)
df1
# Out:
#      name  age gender
# 0  junais   23   male

# %%
#used to print the last rows here specified is 5
df.tail(5)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0

# %%
#here the head part is used to print the first few rows 
#here i mentioned first 10 rows
df.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0
# 5   Honda    Red        42652.0    4.0  23883.0
# 6  Toyota   Blue       163453.0    4.0   8473.0
# 7   Honda  White            NaN    4.0  20306.0
# 8     NaN  White       130538.0    4.0   9374.0
# 9   Honda   Blue        51029.0    4.0  26683.0

# %%
#finding the shape of this 

df.shape
# Out:
# (1000, 5)

# %%
#here i am destructuring the vlaue for the rows and columns 
#checking how many rows and columns are availble here 

row,column =df.shape
print(row)
print(column)
# Out:
# 1000
# 5

# %%
#indexing

df[2:5]
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
#printing the column names 
df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
#used to print the specified column name 

df.Make.head(5)
# Out:
# 0     Honda
# 1       BMW
# 2     Honda
# 3    Toyota
# 4    Nissan
# Name: Make, dtype: object

# %%
#printing specified data of specified column 

df[['Make','Colour','Odometer (KM)']].head(10)
# Out:
#      Make Colour  Odometer (KM)
# 0   Honda  White        35431.0
# 1     BMW   Blue       192714.0
# 2   Honda  White        84714.0
# 3  Toyota  White       154365.0
# 4  Nissan   Blue       181577.0
# 5   Honda    Red        42652.0
# 6  Toyota   Blue       163453.0
# 7   Honda  White            NaN
# 8     NaN  White       130538.0
# 9   Honda   Blue        51029.0

# %%
df.describe()
# Out:
#        Odometer (KM)       Doors         Price
# count     950.000000  950.000000    950.000000
# mean   131253.237895    4.011579  16042.814737
# std     69094.857187    0.382539   8581.695036
# min     10148.000000    3.000000   2796.000000
# 25%     70391.250000    4.000000   9529.250000
# 50%    131821.000000    4.000000  14297.000000
# 75%    192668.500000    4.000000  20806.250000
# max    249860.000000    5.000000  52458.000000

# %%
df['Odometer (KM)'].mean()  #finding the mean
# Out:
# 950

# %%
df['Odometer (KM)'].min()  #finding the min

# %%
df['Odometer (KM)'].max()  #finding the max

# %%
df['Odometer (KM)'].std()  #finding standard deviation

# %%
df['Odometer (KM)'].count()  #finding the count

# %%
# using conditions 

df[df.Price >=3000].head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0
# 5   Honda    Red        42652.0    4.0  23883.0
# 6  Toyota   Blue       163453.0    4.0   8473.0
# 7   Honda  White            NaN    4.0  20306.0
# 8     NaN  White       130538.0    4.0   9374.0
# 9   Honda   Blue        51029.0    4.0  26683.0

# %%
#giving another custom condition 

df[['Make','Colour','Doors']][df['Price']>15000].head(10)
# Out:
#       Make Colour  Doors
# 0    Honda  White    4.0
# 1      BMW   Blue    5.0
# 2    Honda  White    4.0
# 5    Honda    Red    4.0
# 7    Honda  White    4.0
# 9    Honda   Blue    4.0
# 10  Nissan  White    4.0
# 12  Nissan  White    4.0
# 14   Honda   Blue    4.0
# 15  Toyota   Blue    4.0

# %%
df[['Make','Colour','Doors']][df['Price']==df['Price'].max()]
# Out:
#     Make Colour  Doors
# 906  BMW  White    5.0

# %%
#another method is used to set the first colum as the index using the   set_index method

df

df.set_index('Make')  # here if we used to set index of the first column , after running the df it will show the previus data 
#becuase df wont access it , if we want make it pemenant we have to anoter argument inplace=True
# Out:
#        Colour  Odometer (KM)  Doors    Price
# Make
# Honda   White        35431.0    4.0  15323.0
# BMW      Blue       192714.0    5.0  19943.0
# Honda   White        84714.0    4.0  28343.0
# Toyota  White       154365.0    4.0  13434.0
# Nissan   Blue       181577.0    3.0  14043.0
# ...       ...            ...    ...      ...
# Toyota  Black        35820.0    4.0  32042.0
# NaN     White       155144.0    3.0   5716.0
# Nissan   Blue        66604.0    4.0  31570.0
# Honda   White       215883.0    4.0   4001.0
# Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 4 columns]

# %%
#using inplace argument 
df1=df
df1.set_index('Make',inplace=True)
df1
# Out:
#        Colour  Odometer (KM)  Doors    Price
# Make
# Honda   White        35431.0    4.0  15323.0
# BMW      Blue       192714.0    5.0  19943.0
# Honda   White        84714.0    4.0  28343.0
# Toyota  White       154365.0    4.0  13434.0
# Nissan   Blue       181577.0    3.0  14043.0
# ...       ...            ...    ...      ...
# Toyota  Black        35820.0    4.0  32042.0
# NaN     White       155144.0    3.0   5716.0
# Nissan   Blue        66604.0    4.0  31570.0
# Honda   White       215883.0    4.0   4001.0
# Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 4 columns]

# %%
df
# Out:
#        Colour  Odometer (KM)  Doors    Price
# Make
# Honda   White        35431.0    4.0  15323.0
# BMW      Blue       192714.0    5.0  19943.0
# Honda   White        84714.0    4.0  28343.0
# Toyota  White       154365.0    4.0  13434.0
# Nissan   Blue       181577.0    3.0  14043.0
# ...       ...            ...    ...      ...
# Toyota  Black        35820.0    4.0  32042.0
# NaN     White       155144.0    3.0   5716.0
# Nissan   Blue        66604.0    4.0  31570.0
# Honda   White       215883.0    4.0   4001.0
# Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 4 columns]

# %%
#reseting the index to the orginal one 

df.reset_index(inplace=True)
df
# Out:
#      level_0  index    Make Colour  Odometer (KM)  Doors    Price
# 0          0      0   Honda  White        35431.0    4.0  15323.0
# 1          1      1     BMW   Blue       192714.0    5.0  19943.0
# 2          2      2   Honda  White        84714.0    4.0  28343.0
# 3          3      3  Toyota  White       154365.0    4.0  13434.0
# 4          4      4  Nissan   Blue       181577.0    3.0  14043.0
# ..       ...    ...     ...    ...            ...    ...      ...
# 995      995    995  Toyota  Black        35820.0    4.0  32042.0
# 996      996    996     NaN  White       155144.0    3.0   5716.0
# 997      997    997  Nissan   Blue        66604.0    4.0  31570.0
# 998      998    998   Honda  White       215883.0    4.0   4001.0
# 999      999    999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 7 columns]

# %%
#agin setting the index
df.set_index('Make',inplace=True)
df
# Out:
#         level_0  index Colour  Odometer (KM)  Doors    Price
# Make
# Honda         0      0  White        35431.0    4.0  15323.0
# BMW           1      1   Blue       192714.0    5.0  19943.0
# Honda         2      2  White        84714.0    4.0  28343.0
# Toyota        3      3  White       154365.0    4.0  13434.0
# Nissan        4      4   Blue       181577.0    3.0  14043.0
# ...         ...    ...    ...            ...    ...      ...
# Toyota      995    995  Black        35820.0    4.0  32042.0
# NaN         996    996  White       155144.0    3.0   5716.0
# Nissan      997    997   Blue        66604.0    4.0  31570.0
# Honda       998    998  White       215883.0    4.0   4001.0
# Toyota      999    999   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 6 columns]

# %%
df.loc['BMW']  #findinn the rows using the index value BMW
# Out:
#       level_0  index Colour  Odometer (KM)  Doors    Price
# Make
# BMW         1      1   Blue       192714.0    5.0  19943.0
# BMW        17     17  White       194189.0    5.0  17177.0
# BMW        55     55  White        79937.0    5.0  48686.0
# BMW        57     57    Red       162176.0    5.0  19186.0
# BMW        60     60    Red       208124.0    5.0  24668.0
# ...       ...    ...    ...            ...    ...      ...
# BMW       967    967  Green        26839.0    5.0  15224.0
# BMW       969    969   Blue        45207.0    5.0  35254.0
# BMW       971    971  Black       178164.0    3.0  24891.0
# BMW       978    978  White        85739.0    5.0  48419.0
# BMW       994    994   Blue       163322.0    3.0  31666.0
#
# [97 rows x 6 columns]

# %%
df.reset_index(inplace=True) # i tried two or more times thats why this error , it is the currect code only
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24032\2415033437.py in <module>
# ----> 1 df.reset_index(inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5846                     )
#    5847
# -> 5848                 new_obj.insert(0, name, level_values)
#    5849
#    5850         new_obj.index = new_index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4441         if not allow_duplicates and column in self.columns:
# ...

# %%
df
# Out:
#        Make  level_0  index Colour  Odometer (KM)  Doors    Price
# 0     Honda        0      0  White        35431.0    4.0  15323.0
# 1       BMW        1      1   Blue       192714.0    5.0  19943.0
# 2     Honda        2      2  White        84714.0    4.0  28343.0
# 3    Toyota        3      3  White       154365.0    4.0  13434.0
# 4    Nissan        4      4   Blue       181577.0    3.0  14043.0
# ..      ...      ...    ...    ...            ...    ...      ...
# 995  Toyota      995    995  Black        35820.0    4.0  32042.0
# 996     NaN      996    996  White       155144.0    3.0   5716.0
# 997  Nissan      997    997   Blue        66604.0    4.0  31570.0
# 998   Honda      998    998  White       215883.0    4.0   4001.0
# 999  Toyota      999    999   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 7 columns]

# %% [markdown]
# # pandas 2)  topic
#
# ## 1)Read csv
# ## 2)Write csv
# ## 3)read excel
# ## 4)write excel

# %%
read_csv('path',skiprows=)  #this code here it will skip the first row and take the csv file 
read_csv('path',header=none,names=[names]) #in this part it wont take hader instead of we can give the header names as per the data 
read_csv('path',rows=number) #we can give the number of rows we want excluding the header
read_csv('path',na_values=["","",])#it is used to replace the error data which we mentioned in the na_values and change into NaN
also we can provide numbers

another way we can pass these things using dictinary

read_csv('path',na_values={
    columnname:['replacing values']
     columnname:['replacing values']
     columnname:['replacing values']
     columnname:['replacing values']
    etc...
})
df.to_csv('')  #we can write the updated value to the orginal csv or we can create a new csv

#you need to create the csv withe the specified columns 
df.to_csv('',columns=["","",etc])
#removing the header part
df.to_csv('',header=false)


same like in excel but in excel we can creater funcitons and call and use for removing error values

# %% [markdown]
# # pandas 3)  topics
#
# ## fillna -  to fill the missing values uisng different ways
# ## interpolate- to make a guess on missing values using interpoltion
# ## dropna - to drop rows with missing values

# %%
df.head(10)
df.isnull().sum()
# Out:
# Make             49
# level_0           0
# index             0
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
df.isnull()
# Out:
#       Make  level_0  index  Colour  Odometer (KM)  Doors  Price
# 0    False    False  False   False          False  False  False
# 1    False    False  False   False          False  False  False
# 2    False    False  False   False          False  False  False
# 3    False    False  False   False          False  False  False
# 4    False    False  False   False          False  False  False
# ..     ...      ...    ...     ...            ...    ...    ...
# 995  False    False  False   False          False  False  False
# 996   True    False  False   False          False  False  False
# 997  False    False  False   False          False  False  False
# 998  False    False  False   False          False  False  False
# 999  False    False  False   False          False  False  False
#
# [1000 rows x 7 columns]

# %%
df_isnull = df[df['Make'].notnull()]
df_isnull
# Out:
#        Make  level_0  index Colour  Odometer (KM)  Doors    Price
# 0     Honda        0      0  White        35431.0    4.0  15323.0
# 1       BMW        1      1   Blue       192714.0    5.0  19943.0
# 2     Honda        2      2  White        84714.0    4.0  28343.0
# 3    Toyota        3      3  White       154365.0    4.0  13434.0
# 4    Nissan        4      4   Blue       181577.0    3.0  14043.0
# ..      ...      ...    ...    ...            ...    ...      ...
# 994     BMW      994    994   Blue       163322.0    3.0  31666.0
# 995  Toyota      995    995  Black        35820.0    4.0  32042.0
# 997  Nissan      997    997   Blue        66604.0    4.0  31570.0
# 998   Honda      998    998  White       215883.0    4.0   4001.0
# 999  Toyota      999    999   Blue       248360.0    4.0  12732.0
#
# [951 rows x 7 columns]

# %%
df.fillna('thisme') #it will fill null values with the value that we have given
# Out:
#        Make  level_0  index Colour Odometer (KM) Doors    Price
# 0     Honda        0      0  White       35431.0   4.0  15323.0
# 1       BMW        1      1   Blue      192714.0   5.0  19943.0
# 2     Honda        2      2  White       84714.0   4.0  28343.0
# 3    Toyota        3      3  White      154365.0   4.0  13434.0
# 4    Nissan        4      4   Blue      181577.0   3.0  14043.0
# ..      ...      ...    ...    ...           ...   ...      ...
# 995  Toyota      995    995  Black       35820.0   4.0  32042.0
# 996  thisme      996    996  White      155144.0   3.0   5716.0
# 997  Nissan      997    997   Blue       66604.0   4.0  31570.0
# 998   Honda      998    998  White      215883.0   4.0   4001.0
# 999  Toyota      999    999   Blue      248360.0   4.0  12732.0
#
# [1000 rows x 7 columns]

# %%
# another method we can pass a dict to fill the values which is missing

df_new= df.fillna({
    'Make':"mazda",
    'index':4,
    'Price':15000
})

df
# Out:
#        Make  level_0  index Colour  Odometer (KM)  Doors    Price
# 0     Honda        0      0  White        35431.0    4.0  15323.0
# 1       BMW        1      1   Blue       192714.0    5.0  19943.0
# 2     Honda        2      2  White        84714.0    4.0  28343.0
# 3    Toyota        3      3  White       154365.0    4.0  13434.0
# 4    Nissan        4      4   Blue       181577.0    3.0  14043.0
# ..      ...      ...    ...    ...            ...    ...      ...
# 995  Toyota      995    995  Black        35820.0    4.0  32042.0
# 996     NaN      996    996  White       155144.0    3.0   5716.0
# 997  Nissan      997    997   Blue        66604.0    4.0  31570.0
# 998   Honda      998    998  White       215883.0    4.0   4001.0
# 999  Toyota      999    999   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 7 columns]

# %%
df[df['Make']=='thisme'].sum()
# Out:
# Make             0.0
# level_0          0.0
# index            0.0
# Colour           0.0
# Odometer (KM)    0.0
# Doors            0.0
# Price            0.0
# dtype: float64

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [24, None, 22, None, 29],
    'City': ['New York', 'Los Angeles', None, 'Chicago', 'Los Angeles'],
    'Score': [85, 92, None, 76, None],
    'Gender': ['F', 'M', 'M', None, 'F']
}

df2=pd.DataFrame(data)
df2
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob   NaN  Los Angeles   92.0      M
# 2  Charlie  22.0         None    NaN      M
# 3    David   NaN      Chicago   76.0   None
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
df_new = df2.fillna({
    'Age':23,
    'City':'calicut',
    'Gender':'T'
})
df_new
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob  23.0  Los Angeles   92.0      M
# 2  Charlie  22.0      calicut    NaN      M
# 3    David  23.0      Chicago   76.0      T
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
df_new
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob  23.0  Los Angeles   92.0      M
# 2  Charlie  22.0      calicut    NaN      M
# 3    David  23.0      Chicago   76.0      T
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
#another i am using the forward fill  method 

df_new= df2.fillna(method='ffill')
df_new
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob  24.0  Los Angeles   92.0      M
# 2  Charlie  22.0  Los Angeles   92.0      M
# 3    David  22.0      Chicago   76.0      M
# 4      Eve  29.0  Los Angeles   76.0      F

# %%
#another method is used to the backward fill, which means it will copy from the next 

df_new= df2.fillna(method='bfill')
df_new
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob  22.0  Los Angeles   92.0      M
# 2  Charlie  22.0      Chicago   76.0      M
# 3    David  29.0      Chicago   76.0      F
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
df_new=df2.fillna(method='ffill',axis = 'columns')  #axis ways forwardfill the same way we can use back ward fill also 
                                                   
df_new
# Out:
#       Name    Age         City        Score Gender
# 0    Alice   24.0     New York         85.0      F
# 1      Bob    Bob  Los Angeles         92.0      M
# 2  Charlie   22.0         22.0         22.0      M
# 3    David  David      Chicago         76.0   76.0
# 4      Eve   29.0  Los Angeles  Los Angeles      F

# %%
df_new=df2.fillna(method='ffill',limit=2) #also we can pass limit to the funciton  
df_new
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob  24.0  Los Angeles   92.0      M
# 2  Charlie  22.0  Los Angeles   92.0      M
# 3    David  22.0      Chicago   76.0      M
# 4      Eve  29.0  Los Angeles   76.0      F

# %% [markdown]
# using interpolate funcion in pandas

# %%
#function interpolate() is using 

def_new=df2.interpolate(method='ffill')
def_new
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob  24.0  Los Angeles   92.0      M
# 2  Charlie  22.0  Los Angeles   92.0      M
# 3    David  22.0      Chicago   76.0      M
# 4      Eve  29.0  Los Angeles   76.0      F

# %%
def_new=df2.interpolate(method='linear')
def_new
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob  23.0  Los Angeles   92.0      M
# 2  Charlie  22.0         None   84.0      M
# 3    David  25.5      Chicago   76.0   None
# 4      Eve  29.0  Los Angeles   76.0      F

# %%
#here i am using dropna() method to drop the row which has null value 

df2
df_new3=df2.dropna()
df_new3
# Out:
#     Name   Age      City  Score Gender
# 0  Alice  24.0  New York   85.0      F

# %%
df2
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob   NaN  Los Angeles   92.0      M
# 2  Charlie  22.0         None    NaN      M
# 3    David   NaN      Chicago   76.0   None
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
#another one is dropna(how="all")  this one is used to drop the row which has all row having empty value 

df_new3=df2.dropna(how='all')
df_new3
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob   NaN  Los Angeles   92.0      M
# 2  Charlie  22.0         None    NaN      M
# 3    David   NaN      Chicago   76.0   None
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
#anohter is in dropna threshold - here threshold means the row has the specified amount of valid value , 

df2
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob   NaN  Los Angeles   92.0      M
# 2  Charlie  22.0         None    NaN      M
# 3    David   NaN      Chicago   76.0   None
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
df2_new3=df2.dropna(thresh=1)
df2_new3
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob   NaN  Los Angeles   92.0      M
# 2  Charlie  22.0         None    NaN      M
# 3    David   NaN      Chicago   76.0   None
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
df2_new3=df2.dropna(thresh=4)
df2_new3
# Out:
#     Name   Age         City  Score Gender
# 0  Alice  24.0     New York   85.0      F
# 1    Bob   NaN  Los Angeles   92.0      M
# 4    Eve  29.0  Los Angeles    NaN      F

# %% [markdown]
# ## pandas 4) replace method
#
# ### replace()  -function

# %%
#another method is replace method is used to replace the values 

import numpy as np

new_df=df2.replace(24.0,np.NaN)
new_df
# Out:
#       Name   Age         City  Score Gender
# 0    Alice   NaN     New York   85.0      F
# 1      Bob   NaN  Los Angeles   92.0      M
# 2  Charlie  22.0         None    NaN      M
# 3    David   NaN      Chicago   76.0   None
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
#replace method is using in another way by the use of object 

new_df=df2.replace({
    "Name":'Alice',
    'City':'Chicago'
},np.NaN)
new_df
# Out:
#       Name   Age         City  Score Gender
# 0      NaN  24.0     New York   85.0      F
# 1      Bob   NaN  Los Angeles   92.0      M
# 2  Charlie  22.0         None    NaN      M
# 3    David   NaN          NaN   76.0   None
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
#replacing with the missing values only 
df2
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob   NaN  Los Angeles   92.0      M
# 2  Charlie  22.0         None    NaN      M
# 3    David   NaN      Chicago   76.0   None
# 4      Eve  29.0  Los Angeles    NaN      F

# %%
df_new=df2.replace({
    np.NaN:24,
    "None":'Chicago'
})
df_new
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob  24.0  Los Angeles   92.0      M
# 2  Charlie  22.0           24   24.0      M
# 3    David  24.0      Chicago   76.0     24
# 4      Eve  29.0  Los Angeles   24.0      F

# %%
#using reggex expressions for here 

df_new=df2.replace({
    "Gender":'[A-Za-z]'
},'',regex=True)
df_new
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0
# 1      Bob   NaN  Los Angeles   92.0
# 2  Charlie  22.0         None    NaN
# 3    David   NaN      Chicago   76.0   None
# 4      Eve  29.0  Los Angeles    NaN

# %%
df2
# Out:
#       Name   Age         City  Score Gender
# 0    Alice  24.0     New York   85.0      F
# 1      Bob   NaN  Los Angeles   92.0      M
# 2  Charlie  22.0         None    NaN      M
# 3    David   NaN      Chicago   76.0   None
# 4      Eve  29.0  Los Angeles    NaN      F

# %% [markdown]
# # pandas 5) groupby in pands
#
# ## groupby
# ### find the temprature in each cities
# ### find average wind speed per city

# %%
data = {
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 
             'New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'],
    'Day': ['2023-10-01', '2023-10-01', '2023-10-01', '2023-10-01', '2023-10-01',
            '2023-10-02', '2023-10-02', '2023-10-02', '2023-10-02', '2023-10-02'],
    'Temperature': [23, 30, 18, 28, 35, 
                    21, 29, 20, 27, 33],
    'Windspeed': [12, 7, 15, 10, 5, 
                  11, 6, 14, 9, 8],
    'Event': ['Sunny', 'Cloudy', 'Rain', 'Sunny', 'Sunny', 
              'Rain', 'Sunny', 'Cloudy', 'Rain', 'Sunny']
}

df4 = pd.DataFrame(data)
df4
# Out:
#           City         Day  Temperature  Windspeed   Event
# 0     New York  2023-10-01           23         12   Sunny
# 1  Los Angeles  2023-10-01           30          7  Cloudy
# 2      Chicago  2023-10-01           18         15    Rain
# 3      Houston  2023-10-01           28         10   Sunny
# 4      Phoenix  2023-10-01           35          5   Sunny
# 5     New York  2023-10-02           21         11    Rain
# 6  Los Angeles  2023-10-02           29          6   Sunny
# 7      Chicago  2023-10-02           20         14  Cloudy
# 8      Houston  2023-10-02           27          9    Rain
# 9      Phoenix  2023-10-02           33          8   Sunny

# %%
#uisng groupby here 

g=df4.groupby('City')
g

# %%
#using get_group to get the specified group 

g.get_group('New York')
# Out:
#        City         Day  Temperature  Windspeed  Event
# 0  New York  2023-10-01           23         12  Sunny
# 5  New York  2023-10-02           21         11   Rain

# %%
for City in g:
      print(City)
# Out:
# ('Chicago',       City         Day  Temperature  Windspeed   Event
# 2  Chicago  2023-10-01           18         15    Rain
# 7  Chicago  2023-10-02           20         14  Cloudy)
# ('Houston',       City         Day  Temperature  Windspeed  Event
# 3  Houston  2023-10-01           28         10  Sunny
# 8  Houston  2023-10-02           27          9   Rain)
# ('Los Angeles',           City         Day  Temperature  Windspeed   Event
# 1  Los Angeles  2023-10-01           30          7  Cloudy
# 6  Los Angeles  2023-10-02           29          6   Sunny)
# ('New York',        City         Day  Temperature  Windspeed  Event
# 0  New York  2023-10-01           23         12  Sunny
# 5  New York  2023-10-02           21         11   Rain)
# ('Phoenix',       City         Day  Temperature  Windspeed  Event
# 4  Phoenix  2023-10-01           35          5  Sunny
# 9  Phoenix  2023-10-02           33          8  Sunny)

# %%
g.max() #maximum number of tempratuer and windspeed from the group by
# Out:
#                     Day  Temperature  Windspeed  Event
# City
# Chicago      2023-10-02           20         15   Rain
# Houston      2023-10-02           28         10  Sunny
# Los Angeles  2023-10-02           30          7  Sunny
# New York     2023-10-02           23         12  Sunny
# Phoenix      2023-10-02           35          8  Sunny

# %%
g.mean()    #mean or average
# Out:
#              Temperature  Windspeed
# City
# Chicago             19.0       14.5
# Houston             27.5        9.5
# Los Angeles         29.5        6.5
# New York            22.0       11.5
# Phoenix             34.0        6.5

# %%
g.min()
# Out:
#                     Day  Temperature  Windspeed   Event
# City
# Chicago      2023-10-01           18         14  Cloudy
# Houston      2023-10-01           27          9    Rain
# Los Angeles  2023-10-01           29          6  Cloudy
# New York     2023-10-01           21         11    Rain
# Phoenix      2023-10-01           33          5   Sunny

# %%
g.describe()
# Out:
#             Temperature                                                  \
#                   count  mean       std   min    25%   50%    75%   max
# City
# Chicago             2.0  19.0  1.414214  18.0  18.50  19.0  19.50  20.0
# Houston             2.0  27.5  0.707107  27.0  27.25  27.5  27.75  28.0
# Los Angeles         2.0  29.5  0.707107  29.0  29.25  29.5  29.75  30.0
# New York            2.0  22.0  1.414214  21.0  21.50  22.0  22.50  23.0
# Phoenix             2.0  34.0  1.414214  33.0  33.50  34.0  34.50  35.0
#
#             Windspeed
#                 count  mean       std   min    25%   50%    75%   max
# City
# Chicago           2.0  14.5  0.707107  14.0  14.25  14.5  14.75  15.0
# Houston           2.0   9.5  0.707107   9.0   9.25   9.5   9.75  10.0
# Los Angeles       2.0   6.5  0.707107   6.0   6.25   6.5   6.75   7.0
# New York          2.0  11.5  0.707107  11.0  11.25  11.5  11.75  12.0
# Phoenix           2.0   6.5  2.121320   5.0   5.75   6.5   7.25   8.0

# %%
# using matplotlib inline

# %matplotlib inline 

g.plot()
# Out:
# City
# Chicago        AxesSubplot(0.125,0.11;0.775x0.77)
# Houston        AxesSubplot(0.125,0.11;0.775x0.77)
# Los Angeles    AxesSubplot(0.125,0.11;0.775x0.77)
# New York       AxesSubplot(0.125,0.11;0.775x0.77)
# Phoenix        AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# # pandas 6)
# ## concating data frames

# %%
data1 = {
    'Employee_ID': [101, 102, 103, 104, 105],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Department': ['HR', 'IT', 'Finance', 'IT', 'Marketing']
}

df5=pd.DataFrame(data1)
df5
# Out:
#    Employee_ID     Name Department
# 0          101    Alice         HR
# 1          102      Bob         IT
# 2          103  Charlie    Finance
# 3          104    David         IT
# 4          105      Eve  Marketing

# %%
data2={
    'Employee_ID':[106,107,108,109,110],
    'Name':['Junais',"Shahabaz",'Anandh','Farhan','Anas'],
    'Department':['HR','IT',"Finance",'IT',"Marketing"]
}
df6=pd.DataFrame(data2)
df6
# Out:
#    Employee_ID      Name Department
# 0          106    Junais         HR
# 1          107  Shahabaz         IT
# 2          108    Anandh    Finance
# 3          109    Farhan         IT
# 4          110      Anas  Marketing

# %%
new_df=pd.concat([df5,df6],keys=["Strangers","friends"])
new_df
# Out:
#              Employee_ID      Name Department
# Strangers 0          101     Alice         HR
#           1          102       Bob         IT
#           2          103   Charlie    Finance
#           3          104     David         IT
#           4          105       Eve  Marketing
# friends   0          106    Junais         HR
#           1          107  Shahabaz         IT
#           2          108    Anandh    Finance
#           3          109    Farhan         IT
#           4          110      Anas  Marketing

# %%
df6=pd.DataFrame({
    'Name':["junais","Anas","Anshif"],
    "Age":[23,21,22],
    'Qualification':["pg",'Degree','degree']
},index=[0,1,2])

df6
# Out:
#      Name  Age Qualification
# 0  junais   23            pg
# 1    Anas   21        Degree
# 2  Anshif   22        degree

# %%
df7=pd.DataFrame({
    'Name':["junais","Anas","Anshif"],
     "place":["irulam","Karadippara","Metro colony"]
},index=[0,1,2])

df7
# Out:
#      Name         place
# 0  junais        irulam
# 1    Anas   Karadippara
# 2  Anshif  Metro colony

# %%
new_df =pd.concat([df6,df7],axis=1)
new_df
# Out:
#      Name  Age Qualification    Name         place
# 0  junais   23            pg  junais        irulam
# 1    Anas   21        Degree    Anas   Karadippara
# 2  Anshif   22        degree  Anshif  Metro colony

# %% [markdown]
# # pandas 7)
# ## using merge to merge two data frames

# %%
df6 = pd.DataFrame({
    'Customer_ID': [1, 2, 3, 4, 5],
    'Name': ['John', 'Anna', 'Mike', 'Sara', 'Tom'],
    'Country': ['USA', 'Canada', 'USA', 'UK', 'Australia'],
    'Age': [28, 34, 29, 22, 41]
})
df6
# Out:
#    Customer_ID  Name    Country  Age
# 0            1  John        USA   28
# 1            2  Anna     Canada   34
# 2            3  Mike        USA   29
# 3            4  Sara         UK   22
# 4            5   Tom  Australia   41

# %%
df7 =pd.DataFrame({
    'Customer_ID': [1,5,8,9,6],
    'Product': ['Laptop', 'Tablet', 'Phone', 'Monitor', 'Keyboard'],
    'Quantity': [1, 3, 2, 1, 5],
    'Price_per_unit': [1000, 300, 500, 200, 50]
})
df7
# Out:
#    Customer_ID   Product  Quantity  Price_per_unit
# 0            1    Laptop         1            1000
# 1            5    Tablet         3             300
# 2            8     Phone         2             500
# 3            9   Monitor         1             200
# 4            6  Keyboard         5              50

# %%
#uisng merge function to merge the data -- merge function commonly working like joins in sql(inner,outer,left,right)
#here used inner join

df_new=pd.merge(df6,df7,on='Customer_ID',how='inner',indicator=True)
df_new
# Out:
#    Customer_ID  Name    Country  Age Product  Quantity  Price_per_unit _merge
# 0            1  John        USA   28  Laptop         1            1000   both
# 1            5   Tom  Australia   41  Tablet         3             300   both

# %%
#outer

df_new=pd.merge(df6,df7,on='Customer_ID',how='outer',indicator=True)
df_new
# Out:
#    Customer_ID  Name    Country   Age   Product  Quantity  Price_per_unit  \
# 0            1  John        USA  28.0    Laptop       1.0          1000.0
# 1            2  Anna     Canada  34.0       NaN       NaN             NaN
# 2            3  Mike        USA  29.0       NaN       NaN             NaN
# 3            4  Sara         UK  22.0       NaN       NaN             NaN
# 4            5   Tom  Australia  41.0    Tablet       3.0           300.0
# 5            8   NaN        NaN   NaN     Phone       2.0           500.0
# 6            9   NaN        NaN   NaN   Monitor       1.0           200.0
# 7            6   NaN        NaN   NaN  Keyboard       5.0            50.0
#
#        _merge
# 0        both
# 1   left_only
# 2   left_only
# 3   left_only
# 4        both
# 5  right_only
# 6  right_only
# 7  right_only

# %%
#left
df_new=pd.merge(df6,df7,on='Customer_ID',how='left',indicator=True)
df_new
# Out:
#    Customer_ID  Name    Country  Age Product  Quantity  Price_per_unit  \
# 0            1  John        USA   28  Laptop       1.0          1000.0
# 1            2  Anna     Canada   34     NaN       NaN             NaN
# 2            3  Mike        USA   29     NaN       NaN             NaN
# 3            4  Sara         UK   22     NaN       NaN             NaN
# 4            5   Tom  Australia   41  Tablet       3.0           300.0
#
#       _merge
# 0       both
# 1  left_only
# 2  left_only
# 3  left_only
# 4       both

# %%
#right

df_new=pd.merge(df6,df7,on='Customer_ID',how='right',indicator=True)
df_new
# Out:
#    Customer_ID  Name    Country   Age   Product  Quantity  Price_per_unit  \
# 0            1  John        USA  28.0    Laptop         1            1000
# 1            5   Tom  Australia  41.0    Tablet         3             300
# 2            8   NaN        NaN   NaN     Phone         2             500
# 3            9   NaN        NaN   NaN   Monitor         1             200
# 4            6   NaN        NaN   NaN  Keyboard         5              50
#
#        _merge
# 0        both
# 1        both
# 2  right_only
# 3  right_only
# 4  right_only

# %%
#use of suffexes

#if we merge two data frames having the same columns pandas will aotomatically give suffixes for those column names

# %% [markdown]
# # Pandas 7) pivot tables
# ## pivot and pivot_tabel

# %%
import pandas as pd
from datetime import datetime, timedelta

# Generate sample date range
dates = [datetime(2024, 1, 1) + timedelta(days=i) for i in range(10)]

# Sample data
data = {
    'Date': dates,
    'Product': ['Laptop', 'Tablet', 'Phone', 'Monitor', 'Keyboard', 'Laptop', 'Mouse', 'Tablet', 'Phone', 'Monitor'],
    'Quantity_Sold': [5, 3, 8, 2, 10, 7, 12, 5, 6, 4],
    'Revenue': [5000, 900, 4000, 400, 500, 3500, 120, 1500, 3000, 800]
}

df = pd.DataFrame(data)
df
# Out:
#         Date   Product  Quantity_Sold  Revenue
# 0 2024-01-01    Laptop              5     5000
# 1 2024-01-02    Tablet              3      900
# 2 2024-01-03     Phone              8     4000
# 3 2024-01-04   Monitor              2      400
# 4 2024-01-05  Keyboard             10      500
# 5 2024-01-06    Laptop              7     3500
# 6 2024-01-07     Mouse             12      120
# 7 2024-01-08    Tablet              5     1500
# 8 2024-01-09     Phone              6     3000
# 9 2024-01-10   Monitor              4      800

# %%
#here i used pivot table

new=df.pivot(index='Date',columns='Product',values='Revenue')
new
# Out:
# Product     Keyboard  Laptop  Monitor  Mouse   Phone  Tablet
# Date
# 2024-01-01       NaN  5000.0      NaN    NaN     NaN     NaN
# 2024-01-02       NaN     NaN      NaN    NaN     NaN   900.0
# 2024-01-03       NaN     NaN      NaN    NaN  4000.0     NaN
# 2024-01-04       NaN     NaN    400.0    NaN     NaN     NaN
# 2024-01-05     500.0     NaN      NaN    NaN     NaN     NaN
# 2024-01-06       NaN  3500.0      NaN    NaN     NaN     NaN
# 2024-01-07       NaN     NaN      NaN  120.0     NaN     NaN
# 2024-01-08       NaN     NaN      NaN    NaN     NaN  1500.0
# 2024-01-09       NaN     NaN      NaN    NaN  3000.0     NaN
# 2024-01-10       NaN     NaN    800.0    NaN     NaN     NaN

# %%
# pivot table is used to summaize and aggregate data inside dataframe

#using pivot tabel

new1=df.pivot_table(index='Date',columns='Product',aggfunc='sum')  #using the aggfunc method
new1
# Out:
#            Quantity_Sold                                    Revenue          \
# Product         Keyboard Laptop Monitor Mouse Phone Tablet Keyboard  Laptop
# Date
# 2024-01-01           NaN    5.0     NaN   NaN   NaN    NaN      NaN  5000.0
# 2024-01-02           NaN    NaN     NaN   NaN   NaN    3.0      NaN     NaN
# 2024-01-03           NaN    NaN     NaN   NaN   8.0    NaN      NaN     NaN
# 2024-01-04           NaN    NaN     2.0   NaN   NaN    NaN      NaN     NaN
# 2024-01-05          10.0    NaN     NaN   NaN   NaN    NaN    500.0     NaN
# 2024-01-06           NaN    7.0     NaN   NaN   NaN    NaN      NaN  3500.0
# 2024-01-07           NaN    NaN     NaN  12.0   NaN    NaN      NaN     NaN
# 2024-01-08           NaN    NaN     NaN   NaN   NaN    5.0      NaN     NaN
# 2024-01-09           NaN    NaN     NaN   NaN   6.0    NaN      NaN     NaN
# 2024-01-10           NaN    NaN     4.0   NaN   NaN    NaN      NaN     NaN
#
#
# Product    Monitor  Mouse   Phone  Tablet
# ...

# %%
#using grouper function 


new1=df.pivot_table(index=pd.Grouper(freq='N',key='Date'),columns='Product')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24032\1878310427.py in <module>
#       2
#       3
# ----> 4 new1=df.pivot_table(index=pd.Grouper(freq='N',key='Date'),columns='Product')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8045         from pandas.core.reshape.pivot import pivot_table
#    8046
# -> 8047         return pivot_table(
#    8048             self,
#    8049             values=values,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      93         return table.__finalize__(data, method="pivot_table")
#      94
# ---> 95     table = __internal_pivot_table(
# ...

# %% [markdown]
# # pandas 8)melt funciton
# ## uisng melt function

# %%
#melt is used to transform or reshape data 

df
# Out:
#         Date   Product  Quantity_Sold  Revenue
# 0 2024-01-01    Laptop              5     5000
# 1 2024-01-02    Tablet              3      900
# 2 2024-01-03     Phone              8     4000
# 3 2024-01-04   Monitor              2      400
# 4 2024-01-05  Keyboard             10      500
# 5 2024-01-06    Laptop              7     3500
# 6 2024-01-07     Mouse             12      120
# 7 2024-01-08    Tablet              5     1500
# 8 2024-01-09     Phone              6     3000
# 9 2024-01-10   Monitor              4      800

# %%
df1=pd.melt(df,id_vars=["Date"])
df1[df1['variable']=="Product"]
# Out:
#         Date variable     value
# 0 2024-01-01  Product    Laptop
# 1 2024-01-02  Product    Tablet
# 2 2024-01-03  Product     Phone
# 3 2024-01-04  Product   Monitor
# 4 2024-01-05  Product  Keyboard
# 5 2024-01-06  Product    Laptop
# 6 2024-01-07  Product     Mouse
# 7 2024-01-08  Product    Tablet
# 8 2024-01-09  Product     Phone
# 9 2024-01-10  Product   Monitor

# %%
df1=pd.melt(df,id_vars=['Date'],var_name="Items",value_name="Value")
df1
# Out:
#          Date          Items     Value
# 0  2024-01-01        Product    Laptop
# 1  2024-01-02        Product    Tablet
# 2  2024-01-03        Product     Phone
# 3  2024-01-04        Product   Monitor
# 4  2024-01-05        Product  Keyboard
# 5  2024-01-06        Product    Laptop
# 6  2024-01-07        Product     Mouse
# 7  2024-01-08        Product    Tablet
# 8  2024-01-09        Product     Phone
# 9  2024-01-10        Product   Monitor
# 10 2024-01-01  Quantity_Sold         5
# 11 2024-01-02  Quantity_Sold         3
# 12 2024-01-03  Quantity_Sold         8
# 13 2024-01-04  Quantity_Sold         2
# 14 2024-01-05  Quantity_Sold        10
# 15 2024-01-06  Quantity_Sold         7
# 16 2024-01-07  Quantity_Sold        12
# 17 2024-01-08  Quantity_Sold         5
# 18 2024-01-09  Quantity_Sold         6
# 19 2024-01-10  Quantity_Sold         4
# 20 2024-01-01        Revenue      5000
# 21 2024-01-02        Revenue       900
# 22 2024-01-03        Revenue      4000
# ...

# %% [markdown]
# # pandas 8) stacking and unstacking

# %%
new=df.stack()
new=df.unstack()  #it is used like pivot table and one more option is in this is the level which is used to 
                # stack the level of colummn names , example if we have more levels of column it will be helpful 
                # df.stack(level=1)
new
# Out:
# Date           0    2024-01-01 00:00:00
#                1    2024-01-02 00:00:00
#                2    2024-01-03 00:00:00
#                3    2024-01-04 00:00:00
#                4    2024-01-05 00:00:00
#                5    2024-01-06 00:00:00
#                6    2024-01-07 00:00:00
#                7    2024-01-08 00:00:00
#                8    2024-01-09 00:00:00
#                9    2024-01-10 00:00:00
# Product        0                 Laptop
#                1                 Tablet
#                2                  Phone
#                3                Monitor
#                4               Keyboard
#                5                 Laptop
#                6                  Mouse
#                7                 Tablet
#                8                  Phone
#                9                Monitor
# Quantity_Sold  0                      5
#                1                      3
#                2                      8
# ...

# %% [markdown]
# # pandas 9) cross tab

# %%
df
# Out:
#         Date   Product  Quantity_Sold  Revenue
# 0 2024-01-01    Laptop              5     5000
# 1 2024-01-02    Tablet              3      900
# 2 2024-01-03     Phone              8     4000
# 3 2024-01-04   Monitor              2      400
# 4 2024-01-05  Keyboard             10      500
# 5 2024-01-06    Laptop              7     3500
# 6 2024-01-07     Mouse             12      120
# 7 2024-01-08    Tablet              5     1500
# 8 2024-01-09     Phone              6     3000
# 9 2024-01-10   Monitor              4      800

# %%
#using crosstab

pd.crosstab(df.Product,[df.Revenue,df.Date],margins=True)
# Out:
# Revenue         120        400        500        800        900       1500  \
# Date     2024-01-07 2024-01-04 2024-01-05 2024-01-10 2024-01-02 2024-01-08
# Product
# Keyboard          0          0          1          0          0          0
# Laptop            0          0          0          0          0          0
# Monitor           0          1          0          1          0          0
# Mouse             1          0          0          0          0          0
# Phone             0          0          0          0          0          0
# Tablet            0          0          0          0          1          1
# All               1          1          1          1          1          1
#
# Revenue        3000       3500       4000       5000 All
# Date     2024-01-09 2024-01-06 2024-01-03 2024-01-01 NaT
# Product
# Keyboard          0          0          0          0   1
# Laptop            0          1          0          1   2
# ...

# %% [markdown]
# # pandas 9) reading and writing sql query using pandas

# %%
#first we have to use the engine method and data base module to connect 

import the database # which ever it is ex- sqlalchemy 
engine=sqlalchemy.create_engine('connection string')


df=pd.read_sql_table('tablename',engine)
# to_sql is used to add data to the sql

df=pd.to_sql(
name='',
con=engine)

# %% [markdown]
# # pandas 10) time series data analysis in pandas
#
# ## date time index
# ## resampling

# %%
import pandas as pd
from datetime import datetime, timedelta

# Generate sample date range
dates = [datetime(2024, 1, 1) + timedelta(days=i) for i in range(10)]

# Sample data
data = {
    'Date': dates,
    'Product': ['Laptop', 'Tablet', 'Phone', 'Monitor', 'Keyboard', 'Laptop', 'Mouse', 'Tablet', 'Phone', 'Monitor'],
    'Quantity_Sold': [5, 3, 8, 2, 10, 7, 12, 5, 6, 4],
    'Revenue': [5000, 900, 4000, 400, 500, 3500, 120, 1500, 3000, 800]
}

df = pd.DataFrame(data)
df
# Out:
#         Date   Product  Quantity_Sold  Revenue
# 0 2024-01-01    Laptop              5     5000
# 1 2024-01-02    Tablet              3      900
# 2 2024-01-03     Phone              8     4000
# 3 2024-01-04   Monitor              2      400
# 4 2024-01-05  Keyboard             10      500
# 5 2024-01-06    Laptop              7     3500
# 6 2024-01-07     Mouse             12      120
# 7 2024-01-08    Tablet              5     1500
# 8 2024-01-09     Phone              6     3000
# 9 2024-01-10   Monitor              4      800

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.resample('Y').mean()

df['date'] = pd.to_datetime(df['date'])  # Convert 'date' column to datetime
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24032\902523143.py in <module>
# ----> 1 df.resample('Y').mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10548         offset: TimedeltaConvertibleTypes | None = None,
#   10549     ) -> Resampler:
# > 10550         return super().resample(
#   10551             rule=rule,
#   10552             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8311
#    8312         axis = self._get_axis_number(axis)
# -> 8313         return get_resampler(
#    8314             self,
#    8315             freq=rule,
#
# ...

# %%
# setting range to the dataset

import pandas as pd

# Creating a simple DataFrame
data = {
    'Product': ['A', 'B', 'C', 'D'],
    'Sales': [200, 150, 300, 400],
    'Discount': [10, 15, 20, 5],
    'Category': ['Electronics', 'Furniture', 'Electronics', 'Furniture']
}

df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#   Product  Sales  Discount     Category
# 0       A    200        10  Electronics
# 1       B    150        15    Furniture
# 2       C    300        20  Electronics
# 3       D    400         5    Furniture

# %%
#here i am using date_range function to set the range

date=pd.date_range(start="10/06/2022",end="10/06/2023",freq='B')
date
# Out:
# DatetimeIndex(['2022-10-06', '2022-10-07', '2022-10-10', '2022-10-11',
#                '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-17',
#                '2022-10-18', '2022-10-19',
#                ...
#                '2023-09-25', '2023-09-26', '2023-09-27', '2023-09-28',
#                '2023-09-29', '2023-10-02', '2023-10-03', '2023-10-04',
#                '2023-10-05', '2023-10-06'],
#               dtype='datetime64[ns]', length=262, freq='B')

# %%
df.set_index(date,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24032\2407433550.py in <module>
# ----> 1 df.set_index(date,inplace=True)
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5551                 # check newest element against length of calling frame, since
#    5552                 # ensure_index_from_sequences would not raise for append=False.
# -> 5553                 raise ValueError(
#    5554                     f"Length mismatch: Expected {len(self)} rows, "
# ...

# %% [markdown]
# ## need to konw more about time related data , after onwards pandas is almost completed
